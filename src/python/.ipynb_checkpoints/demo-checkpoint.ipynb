# %%
import os
os.path.dirname(os.path.abspath(__file__))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5e2c37702258> in <module>()
#       1 import os
# ----> 2 os.path.dirname(os.path.abspath(__file__))
#
# NameError: name '__file__' is not defined
